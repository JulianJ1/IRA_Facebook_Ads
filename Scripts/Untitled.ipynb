# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
ira_data = pd.read_csv('../Data/data_IRA_Ads.csv', sep=";", parse_dates=['AD_CREATION_DATE', 'AD_END_DATE'], 
                       dayfirst=False, index_col='AD_ID')

# %%
ira_data[:10]
# Out:
#        AD_CLICKS    AD_CREATION_DATE         AD_END_DATE  AD_IMPRESSIONS  \
# AD_ID
# 1              6 2015-10-25 06:28:33 2015-10-27 23:59:00             358
# 2             38 2015-10-20 10:36:20 2015-10-26 08:00:00           17256
# 3              0 2015-10-26 10:45:51 2015-10-27 21:00:59               0
# 4             33 2016-04-19 07:49:45                 NaT           14311
# 5            201 2016-06-15 03:39:52                 NaT           29786
# 6              0 2016-05-12 04:06:17                 NaT               0
# 7             54 2016-05-13 01:18:08                 NaT           23408
# 8             43 2016-03-11 05:04:42                 NaT            9559
# 9             13 2015-11-24 05:34:21                 NaT            4871
# 10            11 2015-11-16 05:49:20                 NaT            1625
#
#                                          AD_LANDING_PAGE  \
# AD_ID
# 1                    https://www.instagram.com/us_daily/
# 2             https://www.instagram.com/south_lone_star/
# 3                https://www.instagram.com/blackunionus/
# 4      https://www.facebook.com/blacklivessss-9301580...
# 5      https://www.facebook.com/govspending-165176135...
# 6          https://www.facebook.com/bat-240131319678646/
# 7          https://www.facebook.com/bat-240131319678646/
# 8         https://www.instagram.com/black—america—today/
# 9                 https://www.instagram.com/veterans_us/
# 10               https://www.instagram.com/gov_spending/
#
#                                AD_PATH     AD_SPEND AD_TARGETING_AGE  \
# AD_ID
# 1      2015-q4/2015-10/P(1)0001736.pdf   161.23 RUB          18 - 51
# 2      2015-q4/2015-10/P(1)0001738.pdf  1000.00 RUB         18 - 65+
# 3      2015-q4/2015-10/P(1)0001740.pdf          NaN         18 - 65+
# 4      2016-q2/2016-04/P(1)0001742.pdf  7575.66 RUB          13 - 44
# 5      2016-q2/2016-06/P(1)0000001.pdf  3714.15 RUB         18 - 65+
# 6      2016-q2/2016-05/P(1)0001744.pdf          NaN          13 - 44
# 7      2016-q2/2016-05/P(1)0001746.pdf  2868.56 RUB          13 - 44
# 8      2016-q1/2016-03/P(1)0006379.pdf  2003.01 RUB          13 - 35
# 9      2015-q4/2015-11/P(1)0001229.pdf  1052.89 RUB         18 - 65+
# 10     2015-q4/2015-11/P(1)0001747.pdf   662.39 RUB         18 - 65+
#
#       AD_TARGETING_CUSTOM_AUDIENCE AD_TARGETING_EXCLUDE  ...  \
# AD_ID                                                    ...
# 1                              NaN                  NaN  ...
# 2                              NaN                  NaN  ...
# 3                              NaN                  NaN  ...
# 4                              NaN                  NaN  ...
# 5                              NaN                  NaN  ...
# 6                              NaN                  NaN  ...
# 7                              NaN                  NaN  ...
# 8                              NaN                  NaN  ...
# 9                              NaN                  NaN  ...
# 10                             NaN                  NaN  ...
#
#       AD_TARGETING_GENDER                             AD_TARGETING_INTERESTS  \
# AD_ID
# 1                     NaN  News broadcasting, Political party, Breaking n...
# 2                     NaN                                                NaN
# 3                     NaN                         Cop Block or Black (Color)
# 4                     NaN                                          Cop Block
# 5                     NaN  Understanding racial segregation in the united...
# 6                     NaN  Christ's Commission Fellowship, Jesus, Jesus D...
# 7                     NaN  Christ's Commission Fellowship, Jesus, Jesus D...
# 8                     NaN                          Hoodies or Trayvon Martin
# 9                     NaN  Veterans Day, American Revolutionary War or Pa...
# 10                    NaN  United States Senate, Election, Government or ...
#
#              AD_TARGETING_LANGUAGE AD_TARGETING_LOCATION  \
# AD_ID
# 1                     English (US)                   NaN
# 2                              NaN                   NaN
# 3                     English (US)                   NaN
# 4                     English (US)         United States
# 5                              NaN                   NaN
# 6                     English (US)         United States
# 7                     English (US)         United States
# 8      English (UK)or English (US)         United States
# 9                     English (US)         United States
# 10                    English (US)         United States
#
#       AD_TARGETING_LOCATION_LIVING_IN AD_TARGETING_LOCATION_RECENTLY_IN  \
# AD_ID
# 1                       United States                               NaN
# 2                United States: Texas                               NaN
# 3                       United States                               NaN
# 4                                 NaN                               NaN
# 5              United States: Georgia                               NaN
# 6                                 NaN                               NaN
# 7                                 NaN                               NaN
# 8                                 NaN                               NaN
# 9                                 NaN                               NaN
# 10                                NaN                               NaN
#
#       AD_TARGETING_PEOPLE_WHO_MATCH AD_TARGETING_PLACEMENTS  \
# AD_ID
# 1                               NaN          Instagram Feed
# 2                               NaN          Instagram Feed
# 3                               NaN          Instagram Feed
# 4                               NaN          Instagram Feed
# 5                               NaN          Instagram Feed
# 6                               NaN          Instagram Feed
# 7                               NaN          Instagram Feed
# 8                               NaN          Instagram Feed
# 9                               NaN          Instagram Feed
# 10                              NaN          Instagram Feed
#
#                                                  AD_TEXT AD_POTENTIAL_TARGET
# AD_ID
# 1                                             Instgogogo          52000000.0
# 2      You can go to hell or follow @south_lone_star ...         115000000.0
# 3      Black lives matter because we see what's going...          17000000.0
# 4      Don't Shoot is a community site where you can ...            490000.0
# 5                                   WHERE is your VOICE?                 NaN
# 6      Conservative Christians. Pro-life/ gun/ police...          21000000.0
# 7      Conservative Christians. Pro-life/ gun/ police...          21000000.0
# 8      Trayvon Martin's lawyers wearing hoodies. Wear...             18000.0
# 9      Edward was a combat engineer in Afghanistan wh...           3600000.0
# 10     Unbelievable amount of the US government's was...          29000000.0
#
# [10 rows x 23 columns]
