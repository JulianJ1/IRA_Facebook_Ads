# %% [markdown]
# ## Sentiment Analysis

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer as sid
from nltk.stem import PorterStemmer
from wordcloud import WordCloud
from textblob import TextBlob
from textblob import Word

plot_size = plt.rcParams["figure.figsize"]  

plot_size[0] = 15  
plot_size[1] = 8  
plt.rcParams["figure.figsize"] = plot_size

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AlexanderPC\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\AlexanderPC\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\AlexanderPC\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
na_values = ['nan', 'N/A', 'NaN', 'NaT', '0']
ira_data = pd.read_csv('../Data/data_IRA_Ads.csv', sep=";", parse_dates=['AD_CREATION_DATE', 'AD_END_DATE'], 
                       dayfirst=False, index_col='AD_ID', na_values=na_values)

# %%
ira_data.insert(4, 'AD_CLICKS_PER_VIEW', ira_data['AD_CLICKS']/ira_data['AD_IMPRESSIONS'])

# %%
ira_data.head(10)
# Out:
#        AD_CLICKS    AD_CREATION_DATE         AD_END_DATE  AD_IMPRESSIONS  \
# AD_ID
# 1            6.0 2015-10-25 06:28:33 2015-10-27 23:59:00           358.0
# 2           38.0 2015-10-20 10:36:20 2015-10-26 08:00:00         17256.0
# 3            NaN 2015-10-26 10:45:51 2015-10-27 21:00:59             NaN
# 4           33.0 2016-04-19 07:49:45                 NaT         14311.0
# 5          201.0 2016-06-15 03:39:52                 NaT         29786.0
# 6            NaN 2016-05-12 04:06:17                 NaT             NaN
# 7           54.0 2016-05-13 01:18:08                 NaT         23408.0
# 8           43.0 2016-03-11 05:04:42                 NaT          9559.0
# 9           13.0 2015-11-24 05:34:21                 NaT          4871.0
# 10          11.0 2015-11-16 05:49:20                 NaT          1625.0
#
#        AD_CLICKS_PER_VIEW                                    AD_LANDING_PAGE  \
# AD_ID
# 1                0.016760                https://www.instagram.com/us_daily/
# 2                0.002202         https://www.instagram.com/south_lone_star/
# 3                     NaN            https://www.instagram.com/blackunionus/
# 4                0.002306  https://www.facebook.com/blacklivessss-9301580...
# 5                0.006748  https://www.facebook.com/govspending-165176135...
# 6                     NaN      https://www.facebook.com/bat-240131319678646/
# 7                0.002307      https://www.facebook.com/bat-240131319678646/
# 8                0.004498     https://www.instagram.com/black—america—today/
# 9                0.002669             https://www.instagram.com/veterans_us/
# 10               0.006769            https://www.instagram.com/gov_spending/
#
#                                AD_PATH     AD_SPEND AD_TARGETING_AGE  \
# AD_ID
# 1      2015-q4/2015-10/P(1)0001736.pdf   161.23 RUB          18 - 51
# 2      2015-q4/2015-10/P(1)0001738.pdf  1000.00 RUB         18 - 65+
# 3      2015-q4/2015-10/P(1)0001740.pdf          NaN         18 - 65+
# 4      2016-q2/2016-04/P(1)0001742.pdf  7575.66 RUB          13 - 44
# 5      2016-q2/2016-06/P(1)0000001.pdf  3714.15 RUB         18 - 65+
# 6      2016-q2/2016-05/P(1)0001744.pdf          NaN          13 - 44
# 7      2016-q2/2016-05/P(1)0001746.pdf  2868.56 RUB          13 - 44
# 8      2016-q1/2016-03/P(1)0006379.pdf  2003.01 RUB          13 - 35
# 9      2015-q4/2015-11/P(1)0001229.pdf  1052.89 RUB         18 - 65+
# 10     2015-q4/2015-11/P(1)0001747.pdf   662.39 RUB         18 - 65+
#
#       AD_TARGETING_CUSTOM_AUDIENCE  ... AD_TARGETING_GENDER  \
# AD_ID                               ...
# 1                              NaN  ...                 NaN
# 2                              NaN  ...                 NaN
# 3                              NaN  ...                 NaN
# 4                              NaN  ...                 NaN
# 5                              NaN  ...                 NaN
# 6                              NaN  ...                 NaN
# 7                              NaN  ...                 NaN
# 8                              NaN  ...                 NaN
# 9                              NaN  ...                 NaN
# 10                             NaN  ...                 NaN
#
#                                   AD_TARGETING_INTERESTS  \
# AD_ID
# 1      News broadcasting, Political party, Breaking n...
# 2                                                    NaN
# 3                             Cop Block or Black (Color)
# 4                                              Cop Block
# 5      Understanding racial segregation in the united...
# 6      Christ's Commission Fellowship, Jesus, Jesus D...
# 7      Christ's Commission Fellowship, Jesus, Jesus D...
# 8                              Hoodies or Trayvon Martin
# 9      Veterans Day, American Revolutionary War or Pa...
# 10     United States Senate, Election, Government or ...
#
#              AD_TARGETING_LANGUAGE AD_TARGETING_LOCATION  \
# AD_ID
# 1                     English (US)                   NaN
# 2                              NaN                   NaN
# 3                     English (US)                   NaN
# 4                     English (US)         United States
# 5                              NaN                   NaN
# 6                     English (US)         United States
# 7                     English (US)         United States
# 8      English (UK)or English (US)         United States
# 9                     English (US)         United States
# 10                    English (US)         United States
#
#       AD_TARGETING_LOCATION_LIVING_IN AD_TARGETING_LOCATION_RECENTLY_IN  \
# AD_ID
# 1                       United States                               NaN
# 2                United States: Texas                               NaN
# 3                       United States                               NaN
# 4                                 NaN                               NaN
# 5              United States: Georgia                               NaN
# 6                                 NaN                               NaN
# 7                                 NaN                               NaN
# 8                                 NaN                               NaN
# 9                                 NaN                               NaN
# 10                                NaN                               NaN
#
#       AD_TARGETING_PEOPLE_WHO_MATCH AD_TARGETING_PLACEMENTS  \
# AD_ID
# 1                               NaN          Instagram Feed
# 2                               NaN          Instagram Feed
# 3                               NaN          Instagram Feed
# 4                               NaN          Instagram Feed
# 5                               NaN          Instagram Feed
# 6                               NaN          Instagram Feed
# 7                               NaN          Instagram Feed
# 8                               NaN          Instagram Feed
# 9                               NaN          Instagram Feed
# 10                              NaN          Instagram Feed
#
#                                                  AD_TEXT AD_POTENTIAL_TARGET
# AD_ID
# 1                                             Instgogogo          52000000.0
# 2      You can go to hell or follow @south_lone_star ...         115000000.0
# 3      Black lives matter because we see what's going...          17000000.0
# 4      Don't Shoot is a community site where you can ...            490000.0
# 5                                   WHERE is your VOICE?                 NaN
# 6      Conservative Christians. Pro-life/ gun/ police...          21000000.0
# 7      Conservative Christians. Pro-life/ gun/ police...          21000000.0
# 8      Trayvon Martin's lawyers wearing hoodies. Wear...             18000.0
# 9      Edward was a combat engineer in Afghanistan wh...           3600000.0
# 10     Unbelievable amount of the US government's was...          29000000.0
#
# [10 rows x 24 columns]

# %% [markdown]
# ### Extract Hashtags
# Extracting the Hashtags in case they are needed later

# %%
# function to collect hashtags
def hashtag_extract(x):
    hashtags = []
    # Loop over the words in the tweet
    for i in x:
        ht = re.findall(r"#(\w+)", str(i))
        hashtags.append(ht)

    return hashtags

# %%
HT = hashtag_extract(ira_data['AD_TEXT'])
HT = sum(HT,[])

a = nltk.FreqDist(HT)
d = pd.DataFrame({'Hashtag': list(a.keys()),
                  'Count': list(a.values())})
# selecting top 10 most frequent hashtags     
d = d.nlargest(columns="Count", n = 10) 
#d.plot.bar()
ax = sns.barplot(data=d, x= "Hashtag", y = "Count")
ax.set(ylabel = 'Count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# ### Add column with word count

# %%
ira_data['WORD_COUNT'] = ira_data['AD_TEXT'].apply(lambda x: len(str(x).split(" ")))
ira_data = ira_data[ira_data['WORD_COUNT'] > 4]

# %% [markdown]
# ### Remove hyperlinks

# %%
ira_data['AD_TEXT']=ira_data['AD_TEXT'].str.replace(r'https?:\/\/.*[\r\n]*', '')

# %% [markdown]
# ### Removal of stopwords

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
ira_data['AD_CLEANED_TEXT']=ira_data['AD_TEXT']
ira_data['AD_CLEANED_TEXT'].apply(lambda x: " ".join(x for x in str(x).split() if x not in stop))
# Out:
# AD_ID
# 2       You go hell follow @south_lone_star instead! T...
# 3       Black lives matter see what's going on. We car...
# 4       Don't Shoot community site find recent videos ...
# 6       Conservative Christians. Pro-life/ gun/ police...
# 7       Conservative Christians. Pro-life/ gun/ police...
# 8       Trayvon Martin's lawyers wearing hoodies. Wear...
# 9       Edward combat engineer Afghanistan whose job c...
# 10      Unbelievable amount US government's waste. Joi...
# 11      Veterans Day coming! There many ways show supp...
# 12      It's time us understand deserve best. It's tim...
# 13      The original Statue Liberty France black. The ...
# 14      This military campaign ambiguous given cost ne...
# 15      And would choose u president: create 11200 mil...
# 16      A Wounded Warrior service dog. Support Veteran...
# 17      What know PTSD? There greater agony. PTSD affe...
# 18      What know PTSD? There greater agony. PTSD affe...
# 19      Who save children? Click Learn more! The US Go...
# 20      Click Learn More really love country! A small ...
# 21      Throughout history nation, many wars. The sold...
# 22      Click learn more! See latest breaking news pho...
# 23      TAG YOUR PHOTOS WITH #TXagainst Send us reason...
# 24      TAG YOUR PHOTOS WITH #TXagainst Send us reason...
# 25      Homeland brave. Support veterans! Join us! Vet...
# 26      Home Brave. Support Veterans! Click Learn More...
# 27      Why government wastes $11 MLN per day ISIL Ins...
# 28      How know truth? Click learn more! Wouldn't bet...
# 29      What know PTSD? Do know US Military deaths sin...
# 30      Click learn more! People want look homeless. B...
# 31      Quiz EBONY magazine April 1952. Which Negro? W...
# 32      Heritage hate y'all! Our flag nothing racism! ...
#                               ...
# 3490    Free online player: Just add ur browser jump w...
# 3491    Free online player: Just add ur browser jump w...
# 3492    Free online player! Just add ur browser jump w...
# 3493    Free online player! Just add ur browser jump w...
# 3494    Free online player! Just add ur browser jump w...
# 3495    Free online player: Just add ur browser jump w...
# 3496    Free online player: Just add ur browser jump w...
# 3497    Free online player! Just add ur browser jump w...
# 3498    Free music extension! Be online listen anythin...
# 3499    Free music extension! Be online listen anythin...
# 3500    Free music extension! Be online listen anythin...
# 3501    Free music extension! Be online listen anythin...
# 3502                                    This real problem
# 3503    Thousands Americans already signed petition ba...
# 3504    New petition:Disavow support Clinton political...
# 3505    We call disqualification removal Hillary Clint...
# 3506    Adore Photoshop Happy Snake With A Mouthful Of...
# 3507    Brexit may threat both. researchers think. Str...
# 3508    Natalie Portman big star, even earns significa...
# 3509    Tonight Show Jimmy Fallon popular, people sure...
# 3510    If ever wondered... Q&A What Makes Dreaming So...
# 3511    Do remember Nice Peter vs Epiclloyd rap battle...
# 3512    Why Do We Count Seconds, Hours, Days, And Week...
# 3513    If Spotify looking create new jobs customer se...
# 3514    This year good ones, already know them, here's...
# 3515    How bring peace another nation peace country? ...
# 3516    Korryn Gaines betrayed system designed oppress...
# 3517    We always condemn racism terrorism affect poor...
# 3518    Unite Black people worldwide, weak divided! Wo...
# 3519                      Best patriotic page ever! Join!
# Name: AD_CLEANED_TEXT, Length: 3193, dtype: object

# %% [markdown]
# ### Removal of words with less than 5 characters

# %%
# ira_data['AD_TEXT'] = ira_data['AD_TEXT'].apply(lambda x: ' '.join([w for w in str(x).split() if len(w)>4]))

# %% [markdown]
# ### Stemming
# removal of suffices, like “ing”, “ly”, “s”, etc.

# %%
st = PorterStemmer()
ira_data['AD_CLEANED_TEXT'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# AD_ID
# 2       you can go to hell or follow @south_lone_star ...
# 3       black live matter becaus we see what' go on. W...
# 4       don't shoot is a commun site where you can fin...
# 6       conserv christians. pro-life/ gun/ police/ mil...
# 7       conserv christians. pro-life/ gun/ police/ mil...
# 8       trayvon martin' lawyer wear hoodies. wear hood...
# 9       edward wa a combat engin in afghanistan whose ...
# 10      unbeliev amount of the US government' waste. j...
# 11      veteran day is coming! there are so mani way t...
# 12      it' time for us to understand that we do deser...
# 13      the origin statu of liberti in franc is black....
# 14      thi militari campaign is veri ambigu given tha...
# 15      and what would you choos if u were a president...
# 16      A wound warrior and hi servic dog. support our...
# 17      what do you know about ptsd? there is no great...
# 18      what do you know about ptsd? there is no great...
# 19      who will save the children? click learn more! ...
# 20      click learn more if you realli love your count...
# 21      throughout the histori of our nation, there ha...
# 22      click learn more! see the latest break news ph...
# 23      tag your photo with #txagainst send us the rea...
# 24      tag your photo with #txagainst send us the rea...
# 25      homeland of brave. support our veterans! join ...
# 26      home of the brave. support our veterans! click...
# 27      whi our govern wast $11 mln per day on isil in...
# 28      how to know the truth? click learn more! would...
# 29      what do you know about ptsd? Do you know that ...
# 30      click learn more! peopl don't want to look at ...
# 31      quiz from eboni magazin april 1952. which is n...
# 32      heritag not hate y'all! our flag ha noth to do...
#                               ...
# 3490    free onlin player: just add in ur browser and ...
# 3491    free onlin player: just add in ur browser and ...
# 3492    free onlin player! just add in ur browser and ...
# 3493    free onlin player! just add in ur browser and ...
# 3494    free onlin player! just add in ur browser and ...
# 3495    free onlin player: just add in ur browser and ...
# 3496    free onlin player: just add in ur browser and ...
# 3497    free onlin player! just add in ur browser and ...
# 3498    free music extension! Be onlin and listen anyt...
# 3499    free music extension! Be onlin and listen anyt...
# 3500    free music extension! Be onlin and listen anyt...
# 3501    free music extension! Be onlin and listen anyt...
# 3502                              thi is the real problem
# 3503    thousand of american have alreadi sign a petit...
# 3504    new petition:disavow support for the clinton p...
# 3505    We call for disqualif and remov of hillari cli...
# 3506    ador photoshop happi snake with A mouth Of egg...
# 3507    brexit may be a threat to both. research think...
# 3508    natali portman is a big star, but even she ear...
# 3509    tonight show with jimmi fallon is veri popular...
# 3510    If you ever wondered... q&a what make dream So...
# 3511    Do you rememb the other nice peter vs epiclloy...
# 3512    whi Do We count seconds, hours, days, and week...
# 3513    If spotifi is look to creat some new job a cus...
# 3514    thi year had some good ones, but you alreadi k...
# 3515    how can you bring peac to anoth nation when yo...
# 3516    korryn gain is be betray by the system that wa...
# 3517    We alway condemn racism and terror becaus they...
# 3518    unit black peopl worldwide, for we are weak be...
# 3519                        best patriot page ever! join!
# Name: AD_CLEANED_TEXT, Length: 3193, dtype: object

# %% [markdown]
# ### Lemmatization
# converts the word into its root word

# %%
ira_data['AD_CLEANED_TEXT'].apply(lambda x: " ".join([Word(word).lemmatize() for word in str(x).split()]))
# Out:
# AD_ID
# 2       You can go to hell or follow @south_lone_star ...
# 3       Black life matter because we see what's going ...
# 4       Don't Shoot is a community site where you can ...
# 6       Conservative Christians. Pro-life/ gun/ police...
# 7       Conservative Christians. Pro-life/ gun/ police...
# 8       Trayvon Martin's lawyer wearing hoodies. Weari...
# 9       Edward wa a combat engineer in Afghanistan who...
# 10      Unbelievable amount of the US government's was...
# 11      Veterans Day is coming! There are so many way ...
# 12      It's time for u to understand that we do deser...
# 13      The original Statue of Liberty in France is bl...
# 14      This military campaign is very ambiguous given...
# 15      And what would you choose if u were a presiden...
# 16      A Wounded Warrior and his service dog. Support...
# 17      What do you know about PTSD? There is no great...
# 18      What do you know about PTSD? There is no great...
# 19      Who will save the children? Click Learn more! ...
# 20      Click Learn More if you really love your count...
# 21      Throughout the history of our nation, there ha...
# 22      Click learn more! See the latest breaking news...
# 23      TAG YOUR PHOTOS WITH #TXagainst Send u the rea...
# 24      TAG YOUR PHOTOS WITH #TXagainst Send u the rea...
# 25      Homeland of brave. Support our veterans! Join ...
# 26      Home of the Brave. Support our Veterans! Click...
# 27      Why our government waste $11 MLN per day on IS...
# 28      How to know the truth? Click learn more! Would...
# 29      What do you know about PTSD? Do you know that ...
# 30      Click learn more! People don't want to look at...
# 31      Quiz from EBONY magazine April 1952. Which is ...
# 32      Heritage not hate y'all! Our flag ha nothing t...
#                               ...
# 3490    Free online player: Just add in ur browser and...
# 3491    Free online player: Just add in ur browser and...
# 3492    Free online player! Just add in ur browser and...
# 3493    Free online player! Just add in ur browser and...
# 3494    Free online player! Just add in ur browser and...
# 3495    Free online player: Just add in ur browser and...
# 3496    Free online player: Just add in ur browser and...
# 3497    Free online player! Just add in ur browser and...
# 3498    Free music extension! Be online and listen any...
# 3499    Free music extension! Be online and listen any...
# 3500    Free music extension! Be online and listen any...
# 3501    Free music extension! Be online and listen any...
# 3502                             This is the real problem
# 3503    Thousands of Americans have already signed a p...
# 3504    New petition:Disavow support for the Clinton p...
# 3505    We call for disqualification and removal of Hi...
# 3506    Adore Photoshop Happy Snake With A Mouthful Of...
# 3507    Brexit may be a threat to both. researcher thi...
# 3508    Natalie Portman is a big star, but even she ea...
# 3509    Tonight Show with Jimmy Fallon is very popular...
# 3510    If you ever wondered... Q&A What Makes Dreamin...
# 3511    Do you remember the other Nice Peter v Epicllo...
# 3512    Why Do We Count Seconds, Hours, Days, And Week...
# 3513    If Spotify is looking to create some new job a...
# 3514    This year had some good ones, but you already ...
# 3515    How can you bring peace to another nation when...
# 3516    Korryn Gaines is being betrayed by the system ...
# 3517    We always condemn racism and terrorism because...
# 3518    Unite Black people worldwide, for we are weak ...
# 3519                      Best patriotic page ever! Join!
# Name: AD_CLEANED_TEXT, Length: 3193, dtype: object

# %% [markdown]
# ### Lowercase

# %%
ira_data['AD_CLEANED_TEXT']=ira_data['AD_CLEANED_TEXT'].str.replace('[^\w\s]','')
ira_data['AD_CLEANED_TEXT']=ira_data['AD_CLEANED_TEXT'].str.replace("[^a-zA-Z#]", " ")

# %%
ira_data['AD_CLEANED_TEXT'] = ira_data['AD_CLEANED_TEXT'].apply(lambda x: " ".join(x.lower() for x in str(x).split()))

# %% [markdown]
# ### Common word removal
# Removes the 10 most common words

# %%
# freq = pd.Series(' '.join(ira_data['AD_CLEANED_TEXT']).split()).value_counts()[:10]
# freq = list(freq.index)
# ira_data['AD_CLEANED_TEXT']=ira_data['AD_CLEANED_TEXT'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))

# %% [markdown]
# ### Rare words removal
# Removes the 10 most uncommon words

# %%
# freq = pd.Series(' '.join(ira_data['AD_CLEANED_TEXT']).split()).value_counts()[-10:]
# freq = list(freq.index)
# ira_data['AD_CLEANED_TEXT']=ira_data['AD_CLEANED_TEXT'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))

# %%
# ira_data['AD_CLEANED_TEXT']=ira_data['AD_CLEANED_TEXT'].apply(lambda x: str(x).split())

# %% [markdown]
# ### Spelling correction
# check for ur etc. before correction

# %%
# ira_data['AD_CLEANED_TEXT'].apply(lambda x: str(TextBlob(x).correct()))

# %% [markdown]
# ## Sentiment Analysis with TextBlob

# %%
ira_data['AD_TextBlob_POLARITY']=ira_data['AD_CLEANED_TEXT'].apply(lambda x: TextBlob(x).sentiment[0] )
ira_data['AD_TextBlob_SUBJECTIVITY']=ira_data['AD_CLEANED_TEXT'].apply(lambda x: TextBlob(x).sentiment[1] )

# %%
ira_data['AD_TextBlob_Sentiment'] = ira_data['AD_TextBlob_POLARITY'].apply(lambda x: 'positive' if x>0 else ('neutral' if x == 0 else 'negative'))

# %%
ira_data.head()
# Out:
#        AD_CLICKS    AD_CREATION_DATE         AD_END_DATE  AD_IMPRESSIONS  \
# AD_ID
# 2           38.0 2015-10-20 10:36:20 2015-10-26 08:00:00         17256.0
# 3            NaN 2015-10-26 10:45:51 2015-10-27 21:00:59             NaN
# 4           33.0 2016-04-19 07:49:45                 NaT         14311.0
# 6            NaN 2016-05-12 04:06:17                 NaT             NaN
# 7           54.0 2016-05-13 01:18:08                 NaT         23408.0
#
#        AD_CLICKS_PER_VIEW                                    AD_LANDING_PAGE  \
# AD_ID
# 2                0.002202         https://www.instagram.com/south_lone_star/
# 3                     NaN            https://www.instagram.com/blackunionus/
# 4                0.002306  https://www.facebook.com/blacklivessss-9301580...
# 6                     NaN      https://www.facebook.com/bat-240131319678646/
# 7                0.002307      https://www.facebook.com/bat-240131319678646/
#
#                                AD_PATH     AD_SPEND AD_TARGETING_AGE  \
# AD_ID
# 2      2015-q4/2015-10/P(1)0001738.pdf  1000.00 RUB         18 - 65+
# 3      2015-q4/2015-10/P(1)0001740.pdf          NaN         18 - 65+
# 4      2016-q2/2016-04/P(1)0001742.pdf  7575.66 RUB          13 - 44
# 6      2016-q2/2016-05/P(1)0001744.pdf          NaN          13 - 44
# 7      2016-q2/2016-05/P(1)0001746.pdf  2868.56 RUB          13 - 44
#
#       AD_TARGETING_CUSTOM_AUDIENCE  ... AD_TARGETING_LOCATION_RECENTLY_IN  \
# AD_ID                               ...
# 2                              NaN  ...                               NaN
# 3                              NaN  ...                               NaN
# 4                              NaN  ...                               NaN
# 6                              NaN  ...                               NaN
# 7                              NaN  ...                               NaN
#
#       AD_TARGETING_PEOPLE_WHO_MATCH AD_TARGETING_PLACEMENTS  \
# AD_ID
# 2                               NaN          Instagram Feed
# 3                               NaN          Instagram Feed
# 4                               NaN          Instagram Feed
# 6                               NaN          Instagram Feed
# 7                               NaN          Instagram Feed
#
#                                                  AD_TEXT AD_POTENTIAL_TARGET  \
# AD_ID
# 2      You can go to hell or follow @south_lone_star ...         115000000.0
# 3      Black lives matter because we see what's going...          17000000.0
# 4      Don't Shoot is a community site where you can ...            490000.0
# 6      Conservative Christians. Pro-life/ gun/ police...          21000000.0
# 7      Conservative Christians. Pro-life/ gun/ police...          21000000.0
#
#       WORD_COUNT                                    AD_CLEANED_TEXT  \
# AD_ID
# 2             37  you can go to hell or follow south lone star i...
# 3             43  black lives matter because we see whats going ...
# 4             38  dont shoot is a community site where you can f...
# 6              7  conservative christians prolife gun police mil...
# 7              7  conservative christians prolife gun police mil...
#
#       AD_TextBlob_POLARITY AD_TextBlob_SUBJECTIVITY AD_TextBlob_Sentiment
# AD_ID
# 2                 0.000000                 0.000000               neutral
# 3                -0.166667                 0.433333              negative
# 4                -0.075000                 0.487500              negative
# 6                -0.100000                 0.100000              negative
# 7                -0.100000                 0.100000              negative
#
# [5 rows x 29 columns]

# %%
polarity=ira_data[ira_data['AD_TextBlob_SUBJECTIVITY'] < 0.8]
plt.hist(polarity['AD_TextBlob_POLARITY'], histtype='bar')
plt.xlabel('Sentiment')
plt.ylabel('Probability')
plt.title('Histogram of sentiment on IRA Facebook Ads using TextBlob')
# Out:
# Text(0.5, 1.0, 'Histogram of sentiment on IRA Facebook Ads using TextBlob')

# %%
plt.hist(ira_data['AD_TextBlob_SUBJECTIVITY'])
plt.xlabel('Subjectivity')
plt.ylabel('Probability')
plt.title('Histogram of subjectivity on IRA Facebook Ads')
# Out:
# Text(0.5, 1.0, 'Histogram of subjectivity on IRA Facebook Ads')

# %% [markdown]
# ## Sentiment Analysis with VADER

# %%
analyzer = sid()
ira_data['AD_VADER_POLARITY']=ira_data['AD_TEXT'].apply(lambda x: analyzer.polarity_scores(x)['compound'])
ira_data['AD_VADER_Sentiment'] = ira_data['AD_VADER_POLARITY'].apply(lambda x: 'positive' if x>=0.5 else ('negative' if x <= -0.5 else 'neutral'))
ira_data['AD_VADER_Sentiment'].value_counts()
# Out:
# positive    1162
# neutral     1160
# negative     871
# Name: AD_VADER_Sentiment, dtype: int64

# %%
plt.hist(ira_data['AD_VADER_POLARITY'], histtype='bar')
plt.xlabel('Sentiment')
plt.ylabel('Probability')
plt.title('Histogram of sentiment on IRA Facebook Ads using VADER')
# Out:
# Text(0.5, 1.0, 'Histogram of sentiment on IRA Facebook Ads using VADER')

# %%
# TODO Change colour of pos and neg so that they are the same

fig1, ax1 = plt.subplots()
explode = (0.1, 0, 0)
labels='Positive', 'Negative', 'Neutral'
ax1.pie(ira_data['AD_TextBlob_Sentiment'].value_counts(), labels=labels, explode=explode, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 
plt.title('Sentiment with TextBlob')
fig2, ax2 = plt.subplots()
ax2.pie(ira_data['AD_VADER_Sentiment'].value_counts(), explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax2.axis('equal') 
plt.title('Sentiment with VADER')

plt.show()

# %% [markdown]
# * * * * * * * * * *

# %% [markdown]
# ### Most Common words

# %%
all_words = ' '.join([text for text in ira_data['AD_TEXT']])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Most Common words in positive Ads

# %%
ira_data = ira_data[ira_data['AD_TextBlob_Sentiment']==ira_data['AD_VADER_Sentiment']]

# %%
pos_words = ' '.join([text for text in ira_data['AD_CLEANED_TEXT'][ira_data['AD_VADER_Sentiment'] =="positive"]])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(pos_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Most Common words in negative Ads

# %%
neg_words = ' '.join([text for text in ira_data['AD_CLEANED_TEXT'][ira_data['AD_VADER_Sentiment'] =="negative"]])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(neg_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%